# %%
import cv2
from matplotlib import pyplot as plt

# %%
file_name = 'temp/erg_01.jpeg'
image = cv2.imread(file_name)
image = image[250:800, 70:645]
plt.imshow(image)

# %%
cv2.imwrite('temp/crop_erg01.jpg', image)
# Out:
# True
