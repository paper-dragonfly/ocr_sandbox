# %% [markdown]
# # Snip Screen

# %% [markdown]
# #### crop screen into single lines

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
img = cv2.imread('temp/no_noise.jpg')
plt.imshow(img)

# %% [markdown]
# yt:yb, xl,xr

# %%
sr = img[182:400, 380:440]
plt.imshow(sr)
cv2.imwrite('temp/s_sr.jpg', sr)
# Out:
# True

# %%
split = img[180:400, 280:385]
plt.imshow(split)
cv2.imwrite('temp/s_split.jpg', split)
# Out:
# True

# %%
dist = img[180:400, 180:280]
plt.imshow(dist)
cv2.imwrite('temp/s_dist.jpg', dist)
# Out:
# True

# %%
time = img[180:400, 50:180]
plt.imshow(time)
cv2.imwrite('temp/s_time.jpg', time)
# Out:
# True

# %%
summary = img[135:175, 50:480]
plt.imshow(summary)
cv2.imwrite('temp/s_summary.jpg', summary)
# Out:
# True

# %%
date = img[47:100, 10:225]
plt.imshow(date)
cv2.imwrite('temp/s_date.jpg', date)
# Out:
# True

# %%
workout = img[15:55, 10:150]
plt.imshow(workout)
cv2.imwrite('temp/s_wo.jpg', workout)
# Out:
# True
